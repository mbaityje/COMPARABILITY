# %% [markdown]
# ### Novelties since last version
#
# The last version relies on an excel input, which needed a lot of cleaning. This version relies on a cleaner datafile made by Christoph, which requires less preprocessing.

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# # Load data

# %%
data_path = '../data/raw/'
in_file = '20240425_dataset_cleaned.csv'
df=pd.read_csv(data_path+in_file)

# %% [markdown]
# Check that there are no repeated articles

# %%
if df.article.duplicated().any():
    duplicate_idx=df.article.duplicated().index
    print("The following articles seem duplicate",df.article[duplicate_idx])
    raise RuntimeError("There are duplicate entries in the dataset. Instead of going on, please check your dataset")
else:
    print('There are no evident duplicates')
# Out:
# There are no evident duplicates

# %%
#Manual check, in case two duplicates of an article are written in similar way
# df.article.sort_values()

# %%
'''
The different datasets are not written as lists. We change this: at the end of this cell, 
each article is assigned a list of datasets that were used for that article
'''
import re

for i in range(len(df)):
    raw_entry = [df.dataset[i]]
    new_entry = re.split('; |, |;', raw_entry[0])
    df.at[i, 'dataset'] = new_entry.copy()
    
#     for ds in new_entry:
#         print(i,ds)

# %%
# Manually replace entries that correspond to the same dataset, but have a slightly different wording

df.dataset
# Out:
# 0     [Fathead minnow database, Aranda et al. (2017)...
# 1                            [US EPA, Wu et al. (2016)]
# 2             [Japanese Ministry of Environment (2018)]
# 3             [Japanese Ministry of Environment (2018)]
# 4                                     [USEtox database]
# 5     [Maran et al. (2007), Su et al. (2014), Benfen...
# 6     [OECD QSAR Toolbox, Pesticide Properties Datab...
# 7     [ECOTOX Database, Japanese Ministry of the Env...
# 8                                         [PPDB (2015)]
# 9                               [ECOTOX Database, EAT5]
# 10                                    [ECOTOX Database]
# 11    [Threshold Database provided by Procter & Gamb...
# 12    [EPA fathead minnow acute toxicity database (E...
# 13    [Mid-Continent Ecology Division of US EPA ‘Nat...
# 14               [Japanese Ministry of the Environment]
# 15                                    [ECOTOX Database]
# 16                   [Japanese Ministry of Environment]
# 17                 [Jia et al. (2020), ECOTOX Database]
# 18                                    [ECOTOX Database]
# 19    [Eldred et al. (1999), Papa et al. (2005), Lya...
# 20                                    [ECOTOX Database]
# 21    [ECOTOX Database, Cheng et al. (2012), Li et a...
# 22    [ECOTOX Database, eChem, EFSA, HSDB, Russom et...
# 23                                 [Khan et al. (2019)]
# 24       [ECHA’s risk assessment report, other unclear]
# 25                       [OASIS, ECOTOX Database, EAT5]
# 26    [Lyakurwa et al. (2014), Martin and Young (200...
# 27                                 [INERIS, ESIS, ECHA]
# 28    [ECHA, Fathead minnow database, Japanese Natio...
# 29    [OASIS, ECOTOX Database, EAT5, Cassotti et al....
# 30                                    [ECOTOX Database]
# 31    [PBT database, ECOSAR, ECOTOX Database, Aquire...
# 32           [ToxValDB, ECOTOX Database, ECHA database]
# 33                                       [not reported]
# 34       [Toxicity Estimation Software Tool (T.E.S.T.)]
# 35                                    [ECOTOX Database]
# 36    [ECOTOX Database, Toxicity Estimation Software...
# 37           [ToxValDB, ECOTOX Database, ECHA database]
# 38                                   [Li et al. (2017)]
# 39                                          [EnviroTox]
# Name: dataset, dtype: object

# %%
for ds in df.dataset:
    for iis,individual_source in enumerate(ds):
        print(individual_source)
        temp=individual_source.replace('Wu et al. 2016','Wu et al. (2016)')
        temp=temp.replace('Japanese Ministry of Environment (2018)','Japanese Ministry of Environment')
        temp=temp.replace('Japanese Ministry of the Environment','Japanese Ministry of Environment')
        temp=temp.replace('Khan et al. (2019a)','Khan et al. (2019)')
        temp=temp.replace('Khan et al. 2019','Khan et al. (2019)')
        temp=temp.replace('Khan et al. 2019a','Khan et al. (2019)')
        temp=temp.replace('Khan et al. 2019b','Khan et al. (2019)')
        temp=temp.replace('Khan et al. (2019)a','Khan et al. (2019)')
        temp=temp.replace('Khan et al. (2019)b','Khan et al. (2019)')
        temp=temp.replace('not reported','unclear/not reported')
        temp=temp.replace('other unclear','unclear/not reported')
        temp=temp.replace('ECHA database','ECHA')
        temp=temp.replace('ECHA’s risk assessment report','ECHA')
        temp=temp.replace('Pesticide Properties Database (PPDB)','PPDB')
        temp=temp.replace('Pesticides Properties Database (PPDB)','PPDB')
        temp=temp.replace('ECOTOX Database','ECOTOX')
        temp=temp.replace('data provided by Solvay','Solvay')
        temp=temp.replace('','')
        temp=temp.replace('','')
        ds[iis]=temp
        print(ds[iis])
# Out:
# Fathead minnow database
# Fathead minnow database
# Aranda et al. (2017)
# Aranda et al. (2017)
# Singh et al. (2013)
# Singh et al. (2013)
# Wei et al. (2015)
# Wei et al. (2015)
# US EPA
# US EPA
# Wu et al. (2016)
# Wu et al. (2016)
# Japanese Ministry of Environment
# Japanese Ministry of Environment
# Japanese Ministry of Environment
# Japanese Ministry of Environment
# USEtox database
# USEtox database
# Maran et al. (2007)
# Maran et al. (2007)
# Su et al. (2014)
# Su et al. (2014)
# Benfenati (2011)
# Benfenati (2011)
# Russom et al. (1997)
# Russom et al. (1997)
# Office of Pesticide Programs (OPP) Pesticides Ecotoxicity Database
# Office of Pesticide Programs (OPP) Pesticides Ecotoxicity Database
# ECOTOX Database
# ECOTOX
# OECD QSAR Toolbox
# OECD QSAR Toolbox
# PPDB
# PPDB
# AMBIT Database Database
# AMBIT Database Database
# Japanese Ministry of Environment
# Japanese Ministry of Environment
# Khan et al. (2019)
# Khan et al. (2019)
# OECD QSAR Toolbox
# OECD QSAR Toolbox
# PPDB
# PPDB
# Office of Pesticide Programs (OPP) Pesticides Ecotoxicity Database
# Office of Pesticide Programs (OPP) Pesticides Ecotoxicity Database
# European Food Safety Authority (EFSA) Database
# European Food Safety Authority (EFSA) Database
# ECOTOX Database
# ECOTOX
# AMBIT Database Database
# AMBIT Database Database
# ECOTOX Database
# ECOTOX
# Japanese Ministry of Environment
# Japanese Ministry of Environment
# Sheffield et al. (2019)
# Sheffield et al. (2019)
# PPDB (2015)
# PPDB (2015)
# ECOTOX Database
# ECOTOX
# EAT5
# EAT5
# ECOTOX Database
# ECOTOX
# Threshold Database provided by Procter & Gamble
# Threshold Database provided by Procter & Gamble
# ECOSAR
# ECOSAR
# EPA fathead minnow acute toxicity database (EPAFHM)
# EPA fathead minnow acute toxicity database (EPAFHM)
# Hommel compendium
# Hommel compendium
# Mid-Continent Ecology Division of US EPA ‘National Health and Environmental Effect Research Laboratory
# Mid-Continent Ecology Division of US EPA ‘National Health and Environmental Effect Research Laboratory
# Japanese Ministry of Environment
# Japanese Ministry of Environment
# ECOTOX Database
# ECOTOX
# Japanese Ministry of Environment
# Japanese Ministry of Environment
# Jia et al. (2020)
# Jia et al. (2020)
# ECOTOX Database
# ECOTOX
# ECOTOX Database
# ECOTOX
# Eldred et al. (1999)
# Eldred et al. (1999)
# Papa et al. (2005)
# Papa et al. (2005)
# Lyakurwa et al. (2014)
# Lyakurwa et al. (2014)
# OECD QSAR Toolbox
# OECD QSAR Toolbox
# ECOTOX Database
# ECOTOX
# ECOTOX Database
# ECOTOX
# Cheng et al. (2012)
# Cheng et al. (2012)
# Li et al. (2017)
# Li et al. (2017)
# Yang et al. (2019)
# Yang et al. (2019)
# ECOTOX Database
# ECOTOX
# eChem
# eChem
# EFSA
# EFSA
# HSDB
# HSDB
# Russom et al. (1997)
# Russom et al. (1997)
# Devillers (2001)
# Devillers (2001)
# Martin and Young (2001)
# Martin and Young (2001)
# Raevsky et al. (2008)
# Raevsky et al. (2008)
# Environment (2014)
# Environment (2014)
# Austin et al. (2015)
# Austin et al. (2015)
# Toropov 2017
# Toropov 2017
# Khan et al. (2019)
# Khan et al. (2019)
# ECHA
# ECHA
# unclear/not reported
# unclear/unclear/not reported
# OASIS
# OASIS
# ECOTOX Database
# ECOTOX
# EAT5
# EAT5
# Lyakurwa et al. (2014)
# Lyakurwa et al. (2014)
# Martin and Young (2001)
# Martin and Young (2001)
# Russom et al. (1997)
# Russom et al. (1997)
# INERIS
# INERIS
# ESIS
# ESIS
# ECHA
# ECHA
# ECHA
# ECHA
# Fathead minnow database
# Fathead minnow database
# Japanese National Institute of Technology and Evaluation (NITE)
# Japanese National Institute of Technology and Evaluation (NITE)
# ECOTOX Database
# ECOTOX
# OASIS
# OASIS
# ECETOC
# ECETOC
# EFSA
# EFSA
# Cassani et al. (2013)
# Cassani et al. (2013)
# Toropov et al. (2017)
# Toropov et al. (2017)
# Singh et al. (2014)
# Singh et al. (2014)
# Wu et al. (2016)
# Wu et al. (2016)
# Furuhama et al. 2016
# Furuhama et al. 2016
# Khan et al. (2019)
# Khan et al. (2019)
# Khan et al. (2019)
# Khan et al. (2019)
# Khan et al. (2019)
# Khan et al. (2019)
# data provided by Solvay
# Solvay
# OASIS
# OASIS
# ECOTOX Database
# ECOTOX
# EAT5
# EAT5
# Cassotti et al. (2015)
# Cassotti et al. (2015)
# ECOTOX Database
# ECOTOX
# PBT database
# PBT database
# ECOSAR
# ECOSAR
# ECOTOX Database
# ECOTOX
# Aquire
# Aquire
# Canadian Domestic Substances list
# Canadian Domestic Substances list
# EnviChem
# EnviChem
# ToxValDB
# ToxValDB
# ECOTOX Database
# ECOTOX
# ECHA
# ECHA
# unclear/not reported
# unclear/unclear/not reported
# Toxicity Estimation Software Tool (T.E.S.T.)
# Toxicity Estimation Software Tool (T.E.S.T.)
# ECOTOX Database
# ECOTOX
# ECOTOX Database
# ECOTOX
# Toxicity Estimation Software Tool (T.E.S.T.)
# Toxicity Estimation Software Tool (T.E.S.T.)
# ToxValDB
# ToxValDB
# ECOTOX Database
# ECOTOX
# ECHA
# ECHA
# Li et al. (2017)
# Li et al. (2017)
# EnviroTox
# EnviroTox

# %%
# Create a list of all the used datasets

flattened_dataset = sum(df.dataset.values,[])
unique_datasets = np.unique(flattened_dataset)
print("Datasets in our database: ",unique_datasets)
# Out:
# Datasets in our database:  ['AMBIT Database Database' 'Aquire' 'Aranda et al. (2017)'
#  'Austin et al. (2015)' 'Benfenati (2011)'
#  'Canadian Domestic Substances list' 'Cassani et al. (2013)'
#  'Cassotti et al. (2015)' 'Cheng et al. (2012)' 'Devillers (2001)' 'EAT5'
#  'ECETOC' 'ECHA' 'ECOSAR' 'ECOTOX' 'EFSA'
#  'EPA fathead minnow acute toxicity database (EPAFHM)' 'ESIS'
#  'Eldred et al. (1999)' 'EnviChem' 'EnviroTox' 'Environment (2014)'
#  'European Food Safety Authority (EFSA) Database'
#  'Fathead minnow database' 'Furuhama et al. 2016' 'HSDB'
#  'Hommel compendium' 'INERIS' 'Japanese Ministry of Environment'
#  'Japanese National Institute of Technology and Evaluation (NITE)'
#  'Jia et al. (2020)' 'Khan et al. (2019)' 'Li et al. (2017)'
#  'Lyakurwa et al. (2014)' 'Maran et al. (2007)' 'Martin and Young (2001)'
#  'Mid-Continent Ecology Division of US EPA ‘National Health and Environmental Effect Research Laboratory'
#  'OASIS' 'OECD QSAR Toolbox'
#  'Office of Pesticide Programs (OPP) Pesticides Ecotoxicity Database'
#  'PBT database' 'PPDB' 'PPDB (2015)' 'Papa et al. (2005)'
#  'Raevsky et al. (2008)' 'Russom et al. (1997)' 'Sheffield et al. (2019)'
#  'Singh et al. (2013)' 'Singh et al. (2014)' 'Solvay' 'Su et al. (2014)'
#  'Threshold Database provided by Procter & Gamble' 'Toropov 2017'
#  'Toropov et al. (2017)' 'ToxValDB'
#  'Toxicity Estimation Software Tool (T.E.S.T.)' 'US EPA' 'USEtox database'
#  'Wei et al. (2015)' 'Wu et al. (2016)' 'Yang et al. (2019)' 'eChem'
#  'unclear/unclear/not reported']

# %% [markdown]
# # Basic stats

# %% [markdown]
# ## Datasets

# %% [markdown]
# ### Dataset sources
# How many times each dataset is used

# %%
# Create histogram of the datasets
histo_datasets = np.ndarray(len(unique_datasets))

for ids,ds in enumerate(unique_datasets):
    histo_datasets[ids]=flattened_dataset.count(ds)

# %%
fig, ax = plt.subplots(figsize=(16,5), nrows=1, ncols=1)

ax.bar(unique_datasets,histo_datasets)
plt.xticks(rotation=90)
plt.yticks(range(21))
plt.ylabel('Number of studies')
plt.grid(axis='y')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,13), nrows=1, ncols=1)

ax.barh(unique_datasets,histo_datasets)
plt.xticks(rotation=90)
plt.xlabel('Number of studies')

plt.show()

# %% [markdown]
# Same plot, by occurrence

# %%
fig, ax = plt.subplots(figsize=(10,13), nrows=1, ncols=1)

sorted_indices=np.argsort(histo_datasets)

ax.barh(unique_datasets[sorted_indices],histo_datasets[sorted_indices])
plt.xticks([0,5,10,15,20])
plt.grid(axis='x')
plt.xlabel('Number of studies')

plt.show()

# %% [markdown]
# ### Dataset Version

# %% [markdown]
# Count number of times that the dataset version was reported

# %%
df.version.value_counts()

# df.version.plot.pie()
# df.version.hist()
# plt.xticks(rotation=90)
# Out:
# not reported                   28
# single paper                    4
# accessed 17.5.2023              1
# accessed 14.06.2023             1
# march 2014                      1
# accessed 06.11.2020             1
# Version 4.2 of the software     1
# 44819                           1
# 44656                           1
# Name: version, dtype: int64

# %%
# Take the non reported ones, and count all the rest as reported

label_nonreported = df.version.value_counts().index[0]
number_nonreported = df.version.value_counts()[0]+df.version.isnull().sum()

label_reported = 'reported'
number_reported = len(df.version)-number_nonreported

# %%
fig, ax = plt.subplots(figsize=(3,2), nrows=1, ncols=1)

labels=[label_nonreported,label_reported]
bars=[number_nonreported,number_reported]

ax.bar(labels,bars)
# plt.xticks(rotation=90)
# plt.yticks(range(21))
plt.ylabel('Number of studies')
plt.grid(axis='y')
plt.title('Dataset version')
plt.show()

# %% [markdown]
# ### Plot chemical space
#
# This needs to be coarsened in bigger categories

# %%
# Create histogram of the chemical spaces
   
fig, ax = plt.subplots(figsize=(10,16), nrows=1, ncols=1)

ax.barh(df['dataset_chemical_space'].value_counts().index,df['dataset_chemical_space'].value_counts().to_numpy())
plt.xlabel('Number of studies')

plt.show()

# %% [markdown]
# ### Plot taxonomic space
#
# This data needs to be coarsened into categories

# %%
# Create histogram of the chemical spaces
   
fig, ax = plt.subplots(figsize=(10,16), nrows=1, ncols=1)

ax.barh(df['dataset_tax_space'].value_counts().index,df['dataset_tax_space'].value_counts().to_numpy())
plt.xlabel('Number of studies')

plt.show()
# Out:
# ) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### Plot experiment space

# %%
df.columns
# Out:
# Index(['entry_id', 'article', 'article_short', 'dataset', 'version',
#        'dataset_chemical_space', 'dataset_tax_space', 'dataset_expspace',
#        'aggregation', 'missing_values', 'missing_values_desc',
#        'standardization', 'standardization_desc', 'outliers_removed',
#        'outliers_desc', 'modeling_task', 'effect_type', 'effect_endpoint',
#        'splitting', 'splitting_desc', 'splitting_exact', 'splitting_ratio',
#        'code_reported', 'metrics_clear', 'performance_metrics',
#        'dataset_availability'],
#       dtype='object')

# %%
df.dataset_tax_space
# Out:
# 0                                  several fish species
# 1                  Fathead minnow (Pimephales promelas)
# 2                                       Oryzias latipes
# 3                                       Oryzias latipes
# 4                                          not reported
# 5     Brachydanio rerio, Pimephales promelas, Cyprin...
# 6     Brachydanio rerio, Pimephales promelas, Cyprin...
# 7                                   fish, not specified
# 8     freshwater fish (Oncorhynchus mykiss, Lepomis ...
# 9                  Fathead minnow (Pimephales promelas)
# 10                OECD accepted freshwater fish species
# 11                                   juvenile fish; FET
# 12    Pimephales promelas (training set), diverse fi...
# 13    fathead minnow, comparative data for species r...
# 14                                      Oryzias latipes
# 15    rainbow trout, fathead minnow, bluegill sunfis...
# 16                                      Oryzias latipes
# 17                            Rainbow trout (O. mykiss)
# 18    Freshwater fish species, native or naturalized...
# 19                                       fathead minnow
# 20                                     345 fish species
# 21    Bluegill sunfish, rainbow trout, fathead minno...
# 22    Pimephales promelas; Oryzias latipes; Oncorhyn...
# 23                                         not reported
# 24                                  Pimephales promelas
# 25                                  Pimephales promelas
# 26                                  Pimephales promelas
# 27                                         not reported
# 28                                  fish, not specified
# 29                                  Pimephales promelas
# 30                                          351 species
# 31                                       fathead minnow
# 32    fish,  358 species for LC50 model, 221 species...
# 33                                 daphnia; algae; fish
# 34                                       fathead minnow
# 35                                 1506 aquatic species
# 36                                       fathead minnow
# 37    Tilapia zillii; Oreochromis niloticus; Oreochr...
# 38    Oncorhynchus mykiss (Rainbow Trout);\r\nLepomi...
# 39    93 fish species, at least one freshwater life ...
# Name: dataset_tax_space, dtype: object

# %% [markdown]
# # Dataset comparable?

# %%
df.dataset.duplicated()

# %%
df.dataset_availability
